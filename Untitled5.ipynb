# %%
from google.colab import files


uploaded = files.upload()
import pandas as pd
# Out:
#      <input type="file" id="files-b2d78194-8a44-4df7-afc8-e48d76175c5d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2d78194-8a44-4df7-afc8-e48d76175c5d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded["mock_kaggle (1).csv"]))
print(df)
# Out:
#            data  venda  estoque  preco
# 0    2014-01-01      0     4972   1.29
# 1    2014-01-02     70     4902   1.29
# 2    2014-01-03     59     4843   1.29
# 3    2014-01-04     93     4750   1.29
# 4    2014-01-05     96     4654   1.29
# ..          ...    ...      ...    ...
# 932  2016-07-27     98     3179   2.39
# 933  2016-07-28    108     3071   2.39
# 934  2016-07-29    128     4095   2.39
# 935  2016-07-30    270     3825   2.39
# 936  2016-07-31    183     3642   2.39
#
# [937 rows x 4 columns]

# %%
from google.colab import files
import pandas as pd
import io
import numpy as np
from datetime import datetime


uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded["mock_kaggle (1).csv"]))


cols_with_missing = df.columns[df.isna().any()].tolist()

for col in cols_with_missing:
    if pd.api.types.is_numeric_dtype(df[col]):
        df[col] = df[col].fillna(df[col].mean())
    else:

        df[col] = df[col].fillna(df[col].mode()[0])

df.drop_duplicates(inplace=True)

#
if 'Date' in df.columns:

    try:
        df['Date'] = pd.to_datetime(df['Date'])
    except ValueError:
        print("Error converting 'Date' column to datetime. Check the date format.")


    df = df.set_index('Date')



print(df.head()) # Check first few rows after pre-processing
# Out:
#      <input type="file" id="files-bb51f404-3f76-44ec-81b5-e1059474b17f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb51f404-3f76-44ec-81b5-e1059474b17f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

# Get the actual key from the uploaded dictionary
file_name = list(uploaded.keys())[0]  # Get the first (and likely only) key

# Read the CSV using the correct key
df = pd.read_csv(io.BytesIO(uploaded[mock_kaggle]))
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-40b1e3b98e30> in <cell line: 0>()
#       6
#       7 # Read the CSV using the correct key
# ----> 8 df = pd.read_csv(io.BytesIO(uploaded[mock_kaggle]))
#       9 print(df)
#
# NameError: name 'mock_kaggle' is not defined
